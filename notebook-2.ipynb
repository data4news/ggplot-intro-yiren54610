# %% [markdown]
# # Plotting univariate data in ggplot
#
# Updating notebook 1 to also include `borough`.

# %% [markdown]
# ### Python and R Setup
#
# This setup allows you to use *Python* and *R* in the same notebook.
#
# To set up a similar notebook, see quickstart instructions here:
#
# https://github.com/dmil/jupyter-quickstart

# %%
# %load_ext rpy2.ipython
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline  
from matplotlib import rcParams
rcParams['figure.figsize'] = (16, 100)

import warnings
from rpy2.rinterface import RRuntimeWarning
warnings.filterwarnings("ignore") # Ignore all warnings
# warnings.filterwarnings("ignore", category=RRuntimeWarning) # Show some warnings

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, HTML

# %%
# %%javascript
# // Disable auto-scrolling
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %% [markdown]
# ### Import packages in R

# %%
# %%R
#
# require("tidyverse")
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Loading required package: tidyverse

# %% [markdown]
# ### Read data

# %%
# %%R
#
# # Read data
# df <- read_csv('housing_data.csv')
# df
# Out:
# Rows: 189 Columns: 12
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): borough
# dbl (11): zip, population, pct_hispanic_or_latino, pct_asian, pct_american_i...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# # A tibble: 189 × 12
#      zip population borough  pct_hispanic_or_latino pct_asian
#    <dbl>      <dbl> <chr>                     <dbl>     <dbl>
#  1 11368     112088 QUEENS                    76.5      11.6
#  2 11385     107796 QUEENS                    45.0       6.46
#  3 11211     103123 BROOKLYN                  24.1       5.53
#  4 11208     101313 BROOKLYN                  40.6       6.01
#  5 10467     101255 BRONX                     52.1       5.68
#  6 11236     100844 BROOKLYN                   7.66      2.58
#  7 11226      99558 BROOKLYN                  16.4       3.07
#  8 11373      94437 QUEENS                    41.7      48.5
#  9 11234      93534 BROOKLYN                  11.1       7.19
# 10 11220      93170 BROOKLYN                  41.3      41.4
# # ℹ 179 more rows
# # ℹ 7 more variables: pct_american_indian_and_alaska_native <dbl>,
# #   pct_black_or_african_american <dbl>, pct_white <dbl>,
# #   pct_native_hawaiian_and_other_pacific_islander <dbl>,
# #   pct_some_other_race <dbl>, pct_two_or_more_races <dbl>,
# #   pct_below_poverty <dbl>
# # ℹ Use `print(n = ...)` to see more rows

# %% [markdown]
# ### Histogram
#
# 👉 Try It
#
# Grab your histogram code from the previous exercise (or just use the sample below)
#
# - modify the code to plot one histogram per borough
# - add a meaningful title and subtitle and axis labels
#
# _(hint: this may require you to look up how `facet_wrap` works)._

# %%
# %%R
#
# ggplot(df) +
#     aes(x=pct_below_poverty) +
#     facet_wrap(~borough) +
#     geom_histogram() +
#     stat_bin(binwidth=20)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.

# %% [markdown]
# ### Dotplot

# %% [markdown]
# 👉 Try It
#
# Grab your dotplot code from the previous exercise (or just use the sample below)
#
# - modify the code to plot one plot per borough
# - add a meaningful title and subtitle and axis labels
#
# _(hint: you might want to change the `y` aesthetic instead of using `facet_wrap`)._

# %%
# %%R -w 1000 -h 200
#
# ggplot(df) +
#     aes(x=pct_below_poverty, y=borough) +
#     geom_point(alpha=.3, size=10)

# %% [markdown]
# ### Dotplot (with jitter)

# %% [markdown]
# 👉 Try It
#
# Grab your dotplot code from the previous exercise (or just use the sample below)
#
# - modify the code to plot one plot per borough
# - add a meaningful title and subtitle and axis labels
#
# _(hint: you might also need to mess with the y axis, but also the colors of the dots)._

# %%
# %%R -w 1000 -h 200
#
# ggplot(df) +
#     aes(x=pct_below_poverty, y=borough, color=borough) +
#     geom_jitter() +
#     labs(title="Poverty in NYC",
#          subtitle="percentage below poverty in each borough in nyc",
#          y="boroughs")

# %% [markdown]
# ### Density Plot

# %% [markdown]
# 👉 Try It
#
# Grab your density plot code from the previous exercise (or just use the sample below)
#
# - modify the code to plot one plot per borough

# %%
# %%R -w 1000 -h 200
# ggplot(df) +
#     aes(x=pct_below_poverty,color=borough) +
#     geom_density()

# %% [markdown]
# ### Box and Whisker Plot
# http://www.sthda.com/english/wiki/ggplot2-box-plot-quick-start-guide-r-software-and-data-visualization

# %% [markdown]
# 👉 Try It
#
# Grab your box and whisker plot code from the previous exercise (or just use the sample below)
#
# - modify the code to plot one plot per borough
# - add a title and subtitle that helps tell a story with this chart
#
# 👉 Bonus
# - see if you can annotate the biggest oulier

# %%
# %%R -w 1000 -h 200
#
# ggplot(df) +
#     aes(x=pct_below_poverty, y=borough,) +
#     geom_boxplot(alpha=.2,outlier.size=10) +
#     labs(title="Bronx fell behind the wealthy city",
#          subtitle="distribution of poor family units in each borough in nyc",
#          y="boroughs")

# %% [markdown]
# ### Violin Plot

# %% [markdown]
# 👉 Try It
#
# Grab your violin plot code from the previous exercise (or just use the sample below)
#
# - modify the code to plot one plot per borough
# - write about how this chart looks different from the box and whisker plot and for what purpose it may be more useful
# > it cannot tell you the percentiles of the data, but I think it can indicate the well-being of the society's ecostructure.

# %%
# %%R -w 1000 -h 200
#
# ggplot(df) +
#     aes(x=pct_below_poverty, y=borough) +
#     geom_violin()

# %% [markdown]
# ### Beeswarm
# 👉 Bonus
#
# Grab your beeswarm code from the previous exercise
#
# - modify the code to plot one plot per borough
# - add a title and subtitle that helps tell a story with this chart

# %%
# %%R
# install.packages("ggbeeswarm")
# library(ggbeeswarm)
# Out:
# --- Please select a CRAN mirror for use in this session ---
# Secure CRAN mirrors
#
#  1: 0-Cloud [https]
#  2: Australia (Canberra) [https]
#  3: Australia (Melbourne 1) [https]
#  4: Australia (Melbourne 2) [https]
#  5: Austria (Wien 1) [https]
#  6: Belgium (Brussels) [https]
#  7: Brazil (PR) [https]
#  8: Brazil (SP 1) [https]
#  9: Brazil (SP 2) [https]
# 10: Bulgaria [https]
# 11: Canada (MB) [https]
# 12: Canada (ON 1) [https]
# 13: Canada (ON 2) [https]
# 14: Chile (Santiago) [https]
# 15: China (Beijing 2) [https]
# 16: China (Beijing 3) [https]
# 17: China (Hefei) [https]
# 18: China (Hong Kong) [https]
# 19: China (Jinan) [https]
# 20: China (Lanzhou) [https]
# 21: China (Nanjing) [https]
# 22: China (Shanghai 2) [https]
# 23: China (Shenzhen) [https]
# 24: China (Wuhan) [https]
# 25: Colombia (Cali) [https]
# 26: Costa Rica [https]
# 27: Cyprus [https]
# 28: Czech Republic [https]
# 29: Denmark [https]
# 30: East Asia [https]
# 31: Ecuador (Cuenca) [https]
# 32: France (Lyon 1) [https]
# 33: France (Lyon 2) [https]
# 34: France (Marseille) [https]
# 35: France (Paris 1) [https]
# 36: Germany (Erlangen) [https]
# 37: Germany (Göttingen) [https]
# 38: Germany (Leipzig) [https]
# 39: Germany (Münster) [https]
# 40: Greece [https]
# 41: Iceland [https]
# 42: India (Bengaluru) [https]
# 43: India (Bhubaneswar) [https]
# 44: Indonesia (Banda Aceh) [https]
# 45: Iran (Mashhad) [https]
# 46: Italy (Milano) [https]
# 47: Italy (Padua) [https]
# 48: Japan (Yonezawa) [https]
# 49: Korea (Gyeongsan-si) [https]
# 50: Mexico (Mexico City) [https]
# 51: Mexico (Texcoco) [https]
# 52: Morocco [https]
# 53: Netherlands (Dronten) [https]
# 54: New Zealand [https]
# 55: South Africa (Johannesburg) [https]
# 56: Spain (A Coruña) [https]
# 57: Spain (Madrid) [https]
# 58: Sweden (Umeå) [https]
# 59: Switzerland (Zurich 1) [https]
# 60: Taiwan (Taipei) [https]
# 61: Turkey (Denizli) [https]
# 62: UK (Bristol) [https]
# 63: UK (London 1) [https]
# 64: USA (IA) [https]
# 65: USA (MI) [https]
# 66: USA (MO) [https]
# 67: USA (OH) [https]
# 68: USA (OR) [https]
# 69: USA (PA 1) [https]
# 70: USA (TN) [https]
# 71: USA (UT) [https]
# 72: United Arab Emirates [https]
# 73: Uruguay [https]
# 74: (other mirrors)
# Selection:  66
# The downloaded binary packages are in
# 	/var/folders/lm/ltt61ln55pdb08_0zxtv_ym40000gn/T//RtmpWCKqjf/downloaded_packages
# also installing the dependencies ‘beeswarm’, ‘vipor’
#
# trying URL 'https://cran.wustl.edu/bin/macosx/big-sur-arm64/contrib/4.4/beeswarm_0.4.0.tgz'
# Content type 'application/x-gzip' length 83134 bytes (81 KB)
# ==================================================
# downloaded 81 KB
#
# trying URL 'https://cran.wustl.edu/bin/macosx/big-sur-arm64/contrib/4.4/vipor_0.4.7.tgz'
# Content type 'application/x-gzip' length 4592052 bytes (4.4 MB)
# ==================================================
# downloaded 4.4 MB
#
# trying URL 'https://cran.wustl.edu/bin/macosx/big-sur-arm64/contrib/4.4/ggbeeswarm_0.7.2.tgz'
# Content type 'application/x-gzip' length 1758231 bytes (1.7 MB)
# ==================================================
# downloaded 1.7 MB
#
# In addition: Warning message:
# In doTryCatch(return(expr), name, parentenv, handler) :
#   unable to load shared object '/Library/Frameworks/R.framework/Resources/modules//R_X11.so':
#   dlopen(/Library/Frameworks/R.framework/Resources/modules//R_X11.so, 0x0006): Library not loaded: /opt/X11/lib/libSM.6.dylib
#   Referenced from: <34C5A480-1AC4-30DF-83C9-30A913FC042E> /Library/Frameworks/R.framework/Versions/4.4-arm64/Resources/modules/R_X11.so
#   Reason: tried: '/opt/X11/lib/libSM.6.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/opt/X11/lib/libSM.6.dylib' (no such file), '/opt/X11/lib/libSM.6.dylib' (no such file), '/usr/local/lib/libSM.6.dylib' (no such file), '/usr/lib/libSM.6.dylib' (no such file, not in dyld cache)

# %%
# %%R
# ggplot(df)+
#     aes(x=pct_below_poverty, y=borough) +
#     geom_beeswarm
# Out:
# ---------------------------------------------------------------------------
# RParsingError                             Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 get_ipython().run_cell_magic('R', '', 'ggplot(df)+\n    aes(x=pct_below_poverty, y=borough) +\n    geom_beeswarm"\n')
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2539 with self.builtin_trap:
#    2540     args = (magic_arg_s, cell)
# -> 2541     result = fn(*args, **kwargs)
#    2543 # The code below prevents the output from being displayed
#    2544 # when using magics with decorator @output_can_be_silenced
#    2545 # when the last Python token in the expression is a ';'.
#    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/rpy2/ipython/rmagic.py:949, in RMagics.R(self, line, cell, local_ns)
#     947         return_output = False
#     948 else:
# --> 949     text_result, result, visible = self.eval(code)
#     950     text_output += text_result
#     951     if visible:
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/rpy2/ipython/rmagic.py:406, in RMagics.eval(self, code)
#     398 stack.enter_context(
#     399     obj_in_module(
#     400         rpy2.rinterface_lib.callbacks,
#     401         '_WRITECONSOLE_EXCEPTION_LOG',
#     402         '%s')
#     403 )
#     404 try:
#     405     # Need the newline in case the last line in code is a comment.
# --> 406     r_expr = ri.parse(code)
#     407     value, visible = ri.evalr_expr_with_visible(
#     408         r_expr
#     409     )
#     410 except (ri.embedded.RRuntimeError, ValueError) as exception:
#     411     # Otherwise next return seems to have copy of error.
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/rpy2/rinterface_lib/conversion.py:45, in _cdata_res_to_rinterface.<locals>._(*args, **kwargs)
#      44 def _(*args, **kwargs):
# ---> 45     cdata = function(*args, **kwargs)
#      46     # TODO: test cdata is of the expected CType
#      47     return _cdata_to_rinterface(cdata)
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/rpy2/rinterface.py:121, in parse(text, num)
#     119 robj = StrSexpVector([text])
#     120 with memorymanagement.rmemory() as rmemory:
# --> 121     res = _rinterface._parse(robj.__sexp__._cdata, num, rmemory)
#     122 return res
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/rpy2/rinterface_lib/_rinterface_capi.py:725, in _parse(cdata, num, rmemory)
#     718 # TODO: design better handling of possible status:
#     719 # PARSE_NULL,
#     720 # PARSE_OK,
#     721 # PARSE_INCOMPLETE,
#     722 # PARSE_ERROR,
#     723 # PARSE_EOF
#     724 if status[0] != openrlib.rlib.PARSE_OK:
# --> 725     raise RParsingError('Parsing status not OK',
#     726                         status=PARSING_STATUS(status[0]))
#     727 return res
#
# RParsingError: Parsing status not OK - PARSING_STATUS.PARSE_INCOMPLETE
